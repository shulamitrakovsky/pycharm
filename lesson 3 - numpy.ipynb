# %%
pip install numpy
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------- -------------------------- 20.5/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 825.8 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/15.5 MB 825.8 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/15.5 MB 825.8 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/15.5 MB 825.8 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/15.5 MB 327.3 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/15.5 MB 327.3 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/15.5 MB 327.3 kB/s eta 0:00:48
# ...

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50, size=(10))
random_int_array
# Out:
# array([ 1, 44, 37, 41, 15, 13,  5, 14, 32, 21])

# %%
np.mean(random_int_array)
# Out:
# 22.3

# %%
random_int_array1 = np.random.randint(1, 10, size=(3, 3))
random_int_array1
# Out:
# array([[9, 5, 5],
#        [2, 8, 1],
#        [6, 6, 2]])

# %%
random_int_array2 = np.random.randint(1, 10, size=(3, 3))
random_int_array2
# Out:
# array([[5, 8, 4],
#        [5, 8, 9],
#        [3, 4, 1]])

# %%
array = np.add(random_int_array1, random_int_array2)

# %%
array
# Out:
# array([[14, 13,  9],
#        [ 7, 16, 10],
#        [ 9, 10,  3]])

# %%
np.mean(array)
# Out:
# 10.11111111111111

# %%
random_int_array = np.random.randint(1, 100, size=(20))
random_int_array
# Out:
# array([82,  3, 30, 88, 58, 90,  4, 93, 10, 65, 69, 56, 57, 89, 44, 30, 72,
#         9, 77, 90])

# %%
condition=random_int_array>50
new_array=random_int_array[condition]
new_array
# Out:
# array([82, 88, 58, 90, 93, 65, 69, 56, 57, 89, 72, 77, 90])

# %%
random_int_array = np.random.randint(1, 10, size=(10))
random_int_array
# Out:
# array([1, 6, 4, 7, 6, 7, 3, 6, 5, 7])

# %%
np.random.shuffle(random_int_array)
random_int_array
# Out:
# array([6, 7, 7, 6, 6, 1, 5, 7, 3, 4])

# %%
np.random.choice(random_int_array)
# Out:
# 7

# %%
np.random.choice(random_int_array)
# Out:
# 3
