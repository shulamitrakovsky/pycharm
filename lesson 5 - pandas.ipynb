# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('cities.csv')

# %%
df
# Out:
#      LatD  LatM  LatS    NS   LonD  LonM  LonS    EW                City State
# 0      41     5    59   "N"   80.0  39.0   0.0   "W"        "Youngstown"    OH
# 1      42    52    48   "N"   97.0  23.0  23.0   "W"           "Yankton"    SD
# 2      46    35    59   "N"  120.0  30.0  36.0   "W"            "Yakima"    WA
# 3      42    16    12   "N"   71.0  48.0   0.0   "W"         "Worcester"    MA
# 4      43    37    48   "N"   89.0  46.0   NaN   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...    ...   ...   ...   ...                 ...   ...
# 123    39    31    12   "N"    NaN  48.0   NaN   "W"              "Reno"    NV
# 124    50    25    11   "N"  104.0  39.0   0.0   "W"            "Regina"    SA
# 125    40    10    48   "N"  122.0  14.0  23.0   "W"         "Red Bluff"    CA
# 126    40    19    48   "N"   75.0   NaN  48.0   "W"           "Reading"    PA
# 127    41     9    35   "N"   81.0  14.0   NaN   "W"           "Ravenna"   OH
#
# [128 rows x 10 columns]

# %%
df.isnull().sum().sum()
# Out:
# 57

# %%
df.isnull().sum()
# Out:
# LatD      0
# LatM      0
# LatS      0
# NS        0
# LonD     12
# LonM     19
# LonS     26
# EW        0
# City      0
# State     0
# dtype: int64

# %%
med = df.LonD.median()
df.LonD = df.LonD.fillna(med)

# %%
df.isnull().sum()
# Out:
# LatD      0
# LatM      0
# LatS      0
# NS        0
# LonD      0
# LonM     19
# LonS     26
# EW        0
# City      0
# State     0
# dtype: int64

# %%
med = df.LonM.median()
df.LonM = df.LonM.fillna(med)
df.isnull().sum()
# Out:
# LatD      0
# LatM      0
# LatS      0
# NS        0
# LonD      0
# LonM      0
# LonS     26
# EW        0
# City      0
# State     0
# dtype: int64

# %%
med = df.LonS.median()
df.LonS = df.LonS.fillna(med)
df.isnull().sum()
# Out:
# LatD     0
# LatM     0
# LatS     0
# NS       0
# LonD     0
# LonM     0
# LonS     0
# EW       0
# City     0
# State    0
# dtype: int64

# %%
duplicate_rows = df.duplicated()
print(duplicate_rows)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# Length: 128, dtype: bool

# %%
df
# Out:
#      LatD  LatM  LatS    NS   LonD  LonM  LonS    EW                City State
# 0      41     5    59   "N"   80.0  39.0   0.0   "W"        "Youngstown"    OH
# 1      42    52    48   "N"   97.0  23.0  23.0   "W"           "Yankton"    SD
# 2      46    35    59   "N"  120.0  30.0  36.0   "W"            "Yakima"    WA
# 3      42    16    12   "N"   71.0  48.0   0.0   "W"         "Worcester"    MA
# 4      43    37    48   "N"   89.0  46.0  23.0   "W"   "Wisconsin Dells"    WI
# ..    ...   ...   ...   ...    ...   ...   ...   ...                 ...   ...
# 123    39    31    12   "N"   89.0  48.0  23.0   "W"              "Reno"    NV
# 124    50    25    11   "N"  104.0  39.0   0.0   "W"            "Regina"    SA
# 125    40    10    48   "N"  122.0  14.0  23.0   "W"         "Red Bluff"    CA
# 126    40    19    48   "N"   75.0  25.0  48.0   "W"           "Reading"    PA
# 127    41     9    35   "N"   81.0  14.0  23.0   "W"           "Ravenna"   OH
#
# [128 rows x 10 columns]

# %%
# ?תרגיל 3 - לא באמת מקבץ

# df['LonD'].groupby('State').mean()
# grouped = df.groupby(['State', 'City'])
# grouped = df.groupby('State')
# average_sales = grouped.mean()
# grouped['State'].agg('State')
# grouped('State').mean()

# grouped = df.groupby('State')
# grouped
# average_sales = grouped['Population'].mean()
# average_sales

# grouped = df.groupby(['State'])
# average_sales = grouped.mean()

# df.groupby(['State', 'City']).mean()

average_population_by_country = df.groupby('State')['LonD'].mean()
average_population_by_country
# Out:
# State
# AL      87.000000
# AZ     110.000000
# BC     123.000000
# CA     117.833333
# CO      99.666667
# CT      73.000000
# DC      77.000000
# DE      75.000000
# FL      81.800000
# GA      82.000000
# IA      94.000000
# ID     114.000000
# IL      88.333333
# IN      87.250000
# KS      96.333333
# LA      93.000000
# MA      71.500000
# MB      97.000000
# MD      75.000000
# MI      84.500000
# MN      93.000000
# MO      92.500000
# MS      89.000000
# NB     103.000000
# NC      78.000000
# ND     100.500000
# NJ      89.000000
# NM     104.500000
# NV      89.000000
# NY      75.200000
# OH      81.600000
# OH      81.000000
# OK      95.500000
# ON      79.000000
# OR      89.000000
# PA      76.666667
# SA     104.000000
# SC      80.000000
# SD      94.333333
# TX      96.875000
# UT     100.000000
# VA      83.750000
# VT      72.000000
# WA     114.333333
# WI      89.000000
# WV      81.000000
# WY     107.500000
# Name: LonD, dtype: float64

# %%
df.drop(['ratio'], axis=1, inplace=True)

# %%
df.insert(10, 'ratio',df['LonD']/df['LatD'])
df
# Out:
#      LatD  LatM  LatS    NS   LonD  LonM  LonS    EW                City  \
# 0      41     5    59   "N"   80.0  39.0   0.0   "W"        "Youngstown"
# 1      42    52    48   "N"   97.0  23.0  23.0   "W"           "Yankton"
# 2      46    35    59   "N"  120.0  30.0  36.0   "W"            "Yakima"
# 3      42    16    12   "N"   71.0  48.0   0.0   "W"         "Worcester"
# 4      43    37    48   "N"   89.0  46.0  23.0   "W"   "Wisconsin Dells"
# ..    ...   ...   ...   ...    ...   ...   ...   ...                 ...
# 123    39    31    12   "N"   89.0  48.0  23.0   "W"              "Reno"
# 124    50    25    11   "N"  104.0  39.0   0.0   "W"            "Regina"
# 125    40    10    48   "N"  122.0  14.0  23.0   "W"         "Red Bluff"
# 126    40    19    48   "N"   75.0  25.0  48.0   "W"           "Reading"
# 127    41     9    35   "N"   81.0  14.0  23.0   "W"           "Ravenna"
#
#     State     ratio
# 0      OH  1.951220
# 1      SD  2.309524
# 2      WA  2.608696
# ...

# %%
df.rename(columns={"Population": "Population"},inplace = True)
df.rename(columns={"LonD": "Population"},inplace = True)
df
# Out:
#      LatD  LatM  LatS    NS  Population  LonM  LonS    EW                City  \
# 0      41     5    59   "N"        80.0  39.0   0.0   "W"        "Youngstown"
# 1      42    52    48   "N"        97.0  23.0  23.0   "W"           "Yankton"
# 2      46    35    59   "N"       120.0  30.0  36.0   "W"            "Yakima"
# 3      42    16    12   "N"        71.0  48.0   0.0   "W"         "Worcester"
# 4      43    37    48   "N"        89.0  46.0  23.0   "W"   "Wisconsin Dells"
# ..    ...   ...   ...   ...         ...   ...   ...   ...                 ...
# 123    39    31    12   "N"        89.0  48.0  23.0   "W"              "Reno"
# 124    50    25    11   "N"       104.0  39.0   0.0   "W"            "Regina"
# 125    40    10    48   "N"       122.0  14.0  23.0   "W"         "Red Bluff"
# 126    40    19    48   "N"        75.0  25.0  48.0   "W"           "Reading"
# 127    41     9    35   "N"        81.0  14.0  23.0   "W"           "Ravenna"
#
#     State     ratio
# ...

# %%
# שאלה 5 לא בדיוק עובד 

sorted = df[df['State']=='CA']
sorted
# Out:
# Empty DataFrame
# Columns: [LatD, LatM, LatS, NS, Population, LonM, LonS, EW, City, State, ratio]
# Index: []

# %%
# df.sort_values(by='Population', ascending=False)
sorted.sort_values(by='Population', ascending=False)
# Out:
# Empty DataFrame
# Columns: [LatD, LatM, LatS, NS, Population, LonM, LonS, EW, City, State, ratio]
# Index: []

# %%
sorted.to_csv("new.csv")
